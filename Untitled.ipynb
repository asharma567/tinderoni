# %%
import joblib

# %%
df_pics_feature_matrix = joblib.load('df_pics_feature_matrix.pkl')

# %%
import numpy as np

unique_idx = np.unique(df_pics_feature_matrix)
new_array = [tuple(row) for row in df_pics_feature_matrix]
print new_arr.shape

print df_pics_feature_matrix.shape
# Out:
# (256,)
# (1723, 300)

# %%
# new_arr = [tuple(row) for row in df_pics_feature_matrix[:5]]
# np.unique(new_arr)
import pandas as pd


print pd.DataFrame(df_pics_feature_matrix).drop_duplicates().shape
print pd.DataFrame(df_pics_feature_matrix).shape
# Out:
# (1193, 300)
# (1723, 300)
