# %%
from helpers import get_access_token

email, password = 'asharma567@ucla.edu', '3.14159265359'
legit_token = get_access_token(email, password)

# %%
import pynder

session = pynder.Session(facebook_token=legit_token)
friends = session.get_fb_friends()

# %%
# Print the names of all facebook friends using Tinder Social.
print(", ".join([x.name for x in friends]))

friends = session.get_fb_friends()
# Get the user_info of these facebook friends.
user_info_objects = []
for friend in friends:
    user_info_objects.append(friend.get_tinder_information())

# Print the bios.
for user_info, friend in zip(user_info_objects, friends):
    print("=" * 50)
    # Use Friend.name, as user_info.name only contains first name.
    print(friend.name)
    print(friend.facebook_link)
    print("-" * 50)
    print(user_info.bio)
    print("=" * 50)

# %%
friends = list(session.get_fb_friends())
# list(friends)

# %%
obj = friends[0]
# Out:
# False

# %%
friends_dict= dict([(friend.name, friend.get_tinder_information()) for friend in friends])
friends_dict
# Out:
# {u'Abhinav Narayanan': u'Abhinav',
#  u'Ajay Sharma': u'Ajay',
#  u'Alex Ho': u'Alex',
#  u'Aman Syal': u'Aman',
#  u'Arjuna Beats': u'Arjuna',
#  u'Ashek Hossain': u'Ashek',
#  u'Babak Golshahi': u'Babak',
#  u'Babak Yasmeh': u'Babak',
#  u'Baturay Akaslan': u'Baturay',
#  u'Billy Davis': u'Billy',
#  u'Brian Noguchi': u'Brian',
#  u'Charan Deep': u'Charan',
#  u'Daniel Agalsoff': u'Daniel',
#  u'Dexter Hart': u'Dexter',
#  u'Eldho Thomas': u'Eldho',
#  u'Eli Ben-Joseph': u'Eli',
#  u'Emilian Sp\xf6rri': u'Emilian',
#  u'Eric Chen': u'Eric',
#  u'Ethan Matkin': u'Ethan',
#  u'Gavin Kiel': u'Gavin',
#  u'Gibran Gian Hasan': u'Gibran',
#  u'Honey Hashemian': u'Honey',
#  u'Hyon S Chu': u'Hyon',
#  u'Jason Kveen': u'Jason',
#  u'Jill McDonald': u'Jill',
#  u'Joe Otonichar': u'Joe',
#  u'Johannes De La Cruz': u'Johannes',
#  u'Johannes Wagener': u'Johannes',
#  u'Jon Herson': u'Jon',
#  u'Jonathan Dinu': u'Jonathan',
#  u'Jonathan Hung': u'Jonathan',
#  u'Joseph Cobian': u'Joseph',
#  u'Josh Sternbach': u'Josh',
#  u'Justin Lippi': u'Justin',
#  u'Kaveh Jam': u'Kaveh',
#  u'Kevin Kim': u'Kevin',
#  u'Kevin Qian': u'Kevin',
#  u'Kimberly Holmes': u'Kimberly',
#  u'Krunal Patel': u'Krunal',
#  u'Lauren Nicholl': u'Lauren',
#  u'Luciano Valencia': u'Luciano',
#  u'Maxi Moon': u'Maxi',
#  u'Michael Bachand': u'Michael',
#  u'Michael Bowman': u'Michael',
#  u'Michael Munson': u'Michael',
#  u'Mike Haier': u'Mike',
#  u'Neha GH': u'Neha',
#  u'Nhan Nguyen': u'Nhan',
#  u'Nikhil Chopra': u'Nikhil',
#  u'Omeed Reza': u'Omeed',
#  u"Osman 'Oz' Javed": u'Osman',
#  u'Pallavi Sekhri': u'Pallavi',
#  u'Pravina Sippy': u'Pravina',
#  u'Prem Natarajan': u'Prem',
#  u'Rachel Munro': u'Rachel',
#  u'Rebecca Vinsonhaler': u'Rebecca',
#  u'Sabir Brara': u'Sabir',
#  u'Sam Payrovi': u'Sam',
#  u'Samy Yadegar': u'Samy',
#  u'Sanjiv Baxi': u'Sanjiv',
#  u'Sean Yoo': u'Sean',
#  u'Shannon White': u'Shannon',
#  u'Shaw Shahbod Namini': u'Shaw',
#  u'Shoeb Mo': u'Shoeb',
#  u'Silvia Encinas-Ramirez': u'Silvia',
#  u'Stephanie Yang': u'Stephanie',
#  u'Vanessa Hurless': u'Vanessa',
#  u'Vikas Erraballi': u'Vikas',
#  u'Will Holleran': u'Will',
#  u'Yas Sanchez': u'Yas',
#  u'Zack DeSario': u'Zack'}
