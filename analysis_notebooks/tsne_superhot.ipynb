# %% [markdown]
# superhot
# --------
#
# 1) does it demonstrate some structure?
# global?
# 3 clusters : i) larger cluster ii) smaller cluster and it's not clear why they were there own cluster, all brunettes and they tend have larger faces than the whole  iii) small 2 pics no similarities
#
# local?
# - distinguishes between margins: two blocks and ovular
# - hair color, blondes are clearly piled up on one end of the cluster and the hair lightens are you go throughout.

# %% [markdown]
# ![title](tsne_trials/CF_super_hot.jpeg)

# %% [markdown]
# in CF_All the pics with the block style margins had mostly hot women in it... that's pretty interesting.. is it the style of taking a picture?

# %% [markdown]
# ![title](tsne_trials/CF_all.jpeg)
