# %%
from image_helpers import *
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/ajay/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
# !ls -t ../data/*.pickle
# Out:
# ../data/tinder_pics_dislikes_faces_encodings.pickle
# ../data/tinder_pics_2017_deduped_faces_encodings.pickle
# ../data/tinder_pics_likes_deduped_faces_encodings.pickle
# ../data/friends_pics_male_faces_encodings.pickle
# ../data/friends_and_myself_pics_faces_encodings.pickle
# ../data/AM_ALL_faces_encodings.pickle
# ../data/tinder_pics_2017_deduped_firsts_faces_encodings.pickle
# ../data/CM_ALL_faces_encodings.pickle
# ../data/AF_ALL_faces_encodings.pickle
# ../data/tinder_pics_dislikes_faces_firsts_deduped_encodings.pickle
# ../data/tinder_pics_likes_faces_deduped_firsts_encodings.pickle
# ../data/friends.pickle
# ../data/CF_ALL_faces_encodings.pickle
# ../data/CF_ALL_encodings.pickle
# ../data/encodings.pickle
# ../data/encodings_likes.pickle
# ../data/test_encodings.pickle

# %%
_, paths, encodings, arrays_rescaled, X = load_encodings('../data/tinder_pics_dislikes_faces_encodings.pickle')

paths, encodings, arrays_rescaled, X = append_new_dataset(paths, encodings, arrays_rescaled, X, '../data/tinder_pics_2017_deduped_faces_encodings.pickle')
paths, encodings, arrays_rescaled, X = append_new_dataset(paths, encodings, arrays_rescaled, X, '../data/tinder_pics_likes_deduped_faces_encodings.pickle')

num_of_dislikes = len(_)
num_of_dislikes
# Out:
# 3429 3429 3429 3429
# 3746 3746 3746 3746
# 2451

# %%
tinder_labels = np.r_[np.zeros(num_of_dislikes), np.ones(len(paths) - num_of_dislikes )]
tinder_labels.shape
# Out:
# (3746,)

# %%
lr = LogisticRegression(class_weight='balanced').fit(encodings, tinder_labels)

score_classifier(lr, encodings, tinder_labels)
# Out:
# (0.8056820612005783,
#  0.8057836261917896,
#  0.009534475353112578,
#  array([0.78937477, 0.80925853, 0.80578363, 0.8189268 , 0.80506658]))

# %%
rf = RandomForestClassifier(class_weight='balanced_subsample').fit(encodings, tinder_labels)

score_classifier(rf, encodings, tinder_labels)
# Out:
# (0.7967184323736964,
#  0.7961705145378615,
#  0.018920388853774325,
#  array([0.79852794, 0.79050902, 0.76973446, 0.79617051, 0.82865022]))

# %%
import pickle
# pickle.dump(lr, open('lr_tinderlikes2.pickle','wb'))
# pickle.dump(rf, open('rf_tinderlikes2.pickle','wb'))
