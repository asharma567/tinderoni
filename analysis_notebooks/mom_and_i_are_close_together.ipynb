# %% [markdown]
# These plots were generated using tsne. It clearly shows how Mom and I are always together and her face 40 years later is still recognizable even with glasses on.

# %% [markdown]
# ![title](tsne_trials/mom_and_and_i1.png)
# ![title](tsne_trials/mom_and_and_i2.png)
# ![title](tsne_trials/mom_and_and_i3.png)
# ![title](tsne_trials/mom_and_and_i4.png)
# ![title](tsne_trials/mom_and_and_i5.png)
