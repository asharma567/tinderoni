# %%
import face_recognition

# %%
import cv2

# %%
from imutils.face_utils import FaceAligner
from imutils.face_utils import rect_to_bb
import argparse
import imutils
import dlib
import cv2
from imutils import paths
import face_recognition
import argparse
import pickle
import cv2
import os

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/ajay/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['gray']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
image
# Out:
# array([[[197, 191, 180],
#         [197, 191, 180],
#         [197, 191, 180],
#         ...,
#         [197, 189, 182],
#         [197, 189, 182],
#         [197, 189, 182]],
#
#        [[197, 191, 180],
#         [197, 191, 180],
#         [198, 192, 181],
#         ...,
#         [198, 190, 183],
#         [197, 189, 182],
#         [197, 189, 182]],
#
#        [[197, 191, 180],
#         [198, 192, 180],
#         [198, 192, 181],
#         ...,
#         [198, 190, 183],
#         [198, 189, 183],
#         [197, 189, 182]],
#
#        ...,
#
#        [[199, 198, 184],
#         [199, 198, 184],
#         [199, 198, 184],
#         ...,
#         [163, 166, 151],
#         [163, 166, 151],
#         [163, 166, 151]],
#
#        [[199, 198, 184],
#         [199, 198, 184],
#         [199, 198, 184],
#         ...,
#         [163, 166, 151],
#         [163, 166, 151],
#         [163, 166, 151]],
#
#        [[199, 198, 184],
#         [199, 198, 184],
#         [199, 198, 184],
#         ...,
#         [163, 166, 151],
#         [163, 166, 151],
#         [163, 166, 151]]], dtype=uint8)

# %%
image2 = cv2.imread('tinder_pics_likes/1525746599_Alex_1.jpeg')

# %%
np.array_equal(image, image2)
# Out:
# True

# %%
image = cv2.imread('tinder_pics_likes/1525746599_Alex_1.jpeg')

# %%
# image
cv2.imshow("Input", image)

# %%
plt.imshow(image)
plt.show()

# %%
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('/Users/ajay/Downloads/face-alignment/shape_predictor_68_face_landmarks.dat')
fa = FaceAligner(predictor, desiredFaceWidth=256)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
rects = detector(gray, 2)
rect=rects[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-5e0d5b8c69f0> in <module>()
# ----> 1 rects = detector(gray, 2)
#       2 rect=rects[0]
#
# TypeError: __call__(): incompatible function arguments. The following argument types are supported:
#     1. (self: dlib.fhog_object_detector, image: array, upsample_num_times: int=0) -> dlib.rectangles
#
# Invoked with: <dlib.fhog_object_detector object at 0x124d233b0>, <function gray at 0x12471b598>, 2

# %%
rect
# Out:
# rectangle(369,84,529,245)

# %%
from imutils.face_utils import rect_to_bb

# %%
(x, y, w, h) = rect_to_bb(rect)
faceOrig = imutils.resize(image[y:y + h, x:x + w], width=256)
(x, y, w, h)
# Out:
# (369, 84, 160, 161)

# %%
plt.imshow(faceOrig)

# %%
image = imutils.resize(image, width=800)

faceAligned = fa.align(image, gray, rect)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-c4fda8887a63> in <module>()
#       1 image = imutils.resize(image, width=800)
#       2
# ----> 3 faceAligned = fa.align(image, gray, rect)
#
# ~/anaconda3/lib/python3.6/site-packages/imutils/face_utils/facealigner.py in align(self, image, gray, rect)
#      22         def align(self, image, gray, rect):
#      23                 # convert the landmark (x, y)-coordinates to a NumPy array
# ---> 24                 shape = self.predictor(gray, rect)
#      25                 shape = shape_to_np(shape)
#      26
#
# TypeError: __call__(): incompatible function arguments. The following argument types are supported:
#     1. (self: dlib.shape_predictor, image: array, box: dlib.rectangle) -> dlib.full_object_detection
#
# Invoked with: <dlib.shape_predictor object at 0x124d23618>, <function gray at 0x12471b598>, rectangle(369,84,529,245)

# %%
plt.imshow(faceAligned)

# %%
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
boxes = face_recognition.face_locations(image,model='cnn')
boxes
# Out:
# [(77, 460, 219, 319)]

# %%
(x, y, w, h) = boxes[0]
faceOrig = imutils.resize(image[y:y + h, x:x + w], width=256)

plt.imshow(faceOrig)

# %%
from imutils.face_utils import FaceAligner
from imutils.face_utils import rect_to_bb
from imutils import paths
import argparse
import dlib
import face_recognition
import argparse
import pickle
import os



def aligner(face_pic, gray, box):   
    
    predictor = dlib.shape_predictor('/Users/ajay/Downloads/face-alignment/shape_predictor_68_face_landmarks.dat')
    
    fa = FaceAligner(predictor, desiredFaceWidth=256)   
    
    faceAligned = fa.align(face_pic, gray, box)
    
    return faceAligned

def get_bounding_box_face(raw_image):
    
    rgb = cv2.cvtColor(raw_image, cv2.COLOR_BGR2RGB)
    boxes = face_recognition.face_locations(image,model='cnn')
    
    return boxes

def get_bounding_box_face2(raw_image):
    
    detector = dlib.get_frontal_face_detector()
    gray = cv2.cvtColor(raw_image, cv2.COLOR_BGR2GRAY)
    boxes = detector(gray, 2)
    return boxes

def crop_out_face(image, box):
    x, y, w, h = box
    return imutils.resize(image[y:y + h, x:x + w], width=256)

image = cv2.imread('tinder_pics_likes/1525746599_Alex_1.jpeg')
image = imutils.resize(image, width=800)

boxes = get_bounding_box_face2(image)

for box in boxes:   
    
    faceOrig = crop_out_face(image, box)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-7b1c72eed4ff> in <module>()
#      45
#      46 for box in boxes:
# ---> 47     faceOrig = crop_out_face(image, box)
#      48
#      49
#
# <ipython-input-58-7b1c72eed4ff> in crop_out_face(image, box)
#      36
#      37 def crop_out_face(image, box):
# ---> 38     x, y, w, h = box
#      39     return imutils.resize(image[y:y + h, x:x + w], width=256)
#      40
#
# TypeError: 'dlib.rectangle' object is not iterable

# %%
plt.imshow(faceOrig)
